# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os
import pandas as pd

# %%
folder_path = '/content/drive/MyDrive/FAERS 212/faers_2024Q4/'

# load in only the drug data files
drug_files = [f for f in os.listdir(folder_path)
              if f.upper().startswith("DRUG") and f.upper().endswith(".TXT")]

# drug_files

# %%
# Collect all drugname entries into a list
all_drugnames = []

for fname in drug_files:
    fpath = os.path.join(folder_path, fname)
    try:
        # only load in drugname col in FAERS datafiles
        df = pd.read_csv(fpath, sep='$', encoding='latin1', dtype=str, usecols=['drugname'])
        all_drugnames.extend(df['drugname'].dropna().tolist())
    except Exception as e:
        print(f"Failed to load {fname}: {e}")
# Out:
# Failed to load DRUG14Q2.txt: Usecols do not match columns, columns expected but not found: ['prod_ai']
# Failed to load DRUG14Q1.txt: Usecols do not match columns, columns expected but not found: ['prod_ai']
# Failed to load DRUG13Q4.txt: Usecols do not match columns, columns expected but not found: ['prod_ai']
# Failed to load DRUG13Q3.txt: Usecols do not match columns, columns expected but not found: ['prod_ai']
# Failed to load DRUG13Q2.txt: Usecols do not match columns, columns expected but not found: ['prod_ai']
# Failed to load DRUG13Q1.txt: Usecols do not match columns, columns expected but not found: ['prod_ai']
# Failed to load drug12q4.txt: Usecols do not match columns, columns expected but not found: ['prod_ai']

# %%
# all_drugnames

# %%
drugnames_df = pd.DataFrame({'drugname': all_drugnames})
drugnames_df
# Out:
#                              drugname
# 0                           LETROZOLE
# 1                           LAPATINIB
# 2                         FULVESTRANT
# 3                        CAPECITABINE
# 4                         TRASTUZUMAB
# ...                               ...
# 68982870         METOPROLOL SUCCINATE
# 68982871  LERCANIDIPINE HYDROCHLORIDE
# 68982872                 EPOPROSTENOL
# 68982873                 EPOPROSTENOL
# 68982874                 EPOPROSTENOL
#
# [68982875 rows x 1 columns]

# %%
drugnames_df = drugnames_df.drop_duplicates()

# %%
drugnames_df.to_csv("all_drugnames.csv", index=False)
